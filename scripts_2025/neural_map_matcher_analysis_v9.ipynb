# %%
import json
unique_name="grid_v8_WeightedBCELoss-lr0.0003-bs1-frac1.0-seed42"
json_file="results_"+unique_name+".json"
with open(json_file) as f:
    results = json.load(f)
# Out:
# Running cells with 'Python 3.8.10' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
item = results[0]
print(item)

# %%
#Load and display the images
import matplotlib.pyplot as plt
import numpy as np
import cv2

base_map=cv2.imread(item["stitched_img_path"])
cv2.imshow(base_map)

stitched_img=cv2.imread(item["stitched_img_path"])
plt.imshow(stitched_img)
